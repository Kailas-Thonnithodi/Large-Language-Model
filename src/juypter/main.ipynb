# %%
import re

# %% [markdown]
# # Reading the file

# %%
file_dir = r'C:\Users\kthon\Github\Public\Large-Language-Model\data\romeo_and_juliet.txt'
with open(file_dir, 'r', encoding='utf-8') as file_with_text:
    text = file_with_text.read()

# %% [markdown]
# ## Tokenisation
# * Splitting the text into certain tokens, then allocating a numerical value to each one.

# %%
def tokenisation(character: str) -> list[str]:
    result = re.split(r'([,.:;?_!"()\']|--|\s)', character)
    return [char.strip() for char in result if char.strip()]

token_splitter(text)
# Out:
# ['\ufeffThe',
#  'Tragedie',
#  'of',
#  'Romeo',
#  'and',
#  'Juliet',
#  'Actus',
#  'Primus',
#  '.',
#  'Scoena',
#  'Prima',
#  '.',
#  'Enter',
#  'Sampson',
#  'and',
#  'Gregory',
#  ',',
#  'with',
#  'Swords',
#  'and',
#  'Bucklers',
#  ',',
#  'of',
#  'the',
#  'House',
#  'of',
#  'Capulet',
#  '.',
#  'Sampson',
#  '.',
#  'Gregory',
#  ':',
#  'A',
#  'my',
#  'word',
#  'wee',
#  "'",
#  'l',
#  'not',
#  'carry',
#  'coales',
#  'Greg',
#  '.',
#  'No',
#  ',',
#  'for',
#  'then',
#  'we',
#  'should',
#  'be',
#  'Colliars',
#  'Samp',
#  '.',
#  'I',
#  'mean',
#  ',',
#  'if',
#  'we',
#  'be',
#  'in',
#  'choller',
#  ',',
#  'wee',
#  "'",
#  'l',
#  'draw',
#  'Greg',
#  '.',
#  'I',
#  ',',
#  'While',
#  'you',
#  'liue',
#  ',',
#  'draw',
#  'your',
#  'necke',
#  'out',
#  'o',
#  "'",
#  'th',
#  'Collar',
#  'Samp',
#  '.',
#  'I',
#  'strike',
#  'quickly',
#  ',',
#  'being',
#  'mou',
#  "'",
#  'd',
#  'Greg',
#  '.',
#  'But',
#  'thou',
# ...
